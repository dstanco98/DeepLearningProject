# %%
# Here I do the git clone of two repositories, the first one contains the G-CNN 
# experiment and the second one is my personal repository for this project
# !git clone https://github.com/adambielski/GrouPy.git
# !git clone https://github.com/dstanco98/DeepLearningProject.git
# Out:
# Cloning into 'GrouPy'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 167 (delta 35), reused 33 (delta 33), pack-reused 119
# Receiving objects: 100% (167/167), 141.59 KiB | 5.66 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Cloning into 'DeepLearningProject'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 53 (delta 5), reused 32 (delta 0), pack-reused 4
# Unpacking objects: 100% (53/53), 80.16 MiB | 9.23 MiB/s, done.

# %%
# %cd GrouPy/
# !python setup.py install
# %cd ..
# Out:
# /kaggle/working/GrouPy
# running install
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/groupy
# copying groupy/__init__.py -> build/lib/groupy
# creating build/lib/groupy/garray
# copying groupy/garray/p4_array.py -> build/lib/groupy/garray
# copying groupy/garray/C4_array.py -> build/lib/groupy/garray
# copying groupy/garray/garray.py -> build/lib/groupy/garray
# copying groupy/garray/p4m_array.py -> build/lib/groupy/garray
# copying groupy/garray/finitegroup.py -> build/lib/groupy/garray
# copying groupy/garray/__init__.py -> build/lib/groupy/garray
# copying groupy/garray/matrix_garray.py -> build/lib/groupy/garray
# copying groupy/garray/Z2_array.py -> build/lib/groupy/garray
# copying groupy/garray/D4_array.py -> build/lib/groupy/garray
# copying groupy/garray/test_garray.py -> build/lib/groupy/garray
# creating build/lib/groupy/gconv
# copying groupy/gconv/__init__.py -> build/lib/groupy/gconv
# copying groupy/gconv/make_gconv_indices.py -> build/lib/groupy/gconv
# creating build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/splitgconv2d.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/transform_filter.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/test_transform_filter.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/__init__.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/test_gconv.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/p4_conv.py -> build/lib/groupy/gconv/chainer_gconv
# copying groupy/gconv/chainer_gconv/p4m_conv.py -> build/lib/groupy/gconv/chainer_gconv
# creating build/lib/groupy/gconv/theano_gconv
# copying groupy/gconv/theano_gconv/__init__.py -> build/lib/groupy/gconv/theano_gconv
# creating build/lib/groupy/gconv/tensorflow_gconv
# copying groupy/gconv/tensorflow_gconv/splitgconv2d.py -> build/lib/groupy/gconv/tensorflow_gconv
# copying groupy/gconv/tensorflow_gconv/transform_filter.py -> build/lib/groupy/gconv/tensorflow_gconv
# copying groupy/gconv/tensorflow_gconv/__init__.py -> build/lib/groupy/gconv/tensorflow_gconv
# copying groupy/gconv/tensorflow_gconv/check_gconv2d.py -> build/lib/groupy/gconv/tensorflow_gconv
# copying groupy/gconv/tensorflow_gconv/check_transform_filter.py -> build/lib/groupy/gconv/tensorflow_gconv
# creating build/lib/groupy/gconv/pytorch_gconv
# copying groupy/gconv/pytorch_gconv/splitgconv2d.py -> build/lib/groupy/gconv/pytorch_gconv
# copying groupy/gconv/pytorch_gconv/__init__.py -> build/lib/groupy/gconv/pytorch_gconv
# copying groupy/gconv/pytorch_gconv/pooling.py -> build/lib/groupy/gconv/pytorch_gconv
# copying groupy/gconv/pytorch_gconv/check_gconv2d.py -> build/lib/groupy/gconv/pytorch_gconv
# copying groupy/gconv/pytorch_gconv/check_transform_filter.py -> build/lib/groupy/gconv/pytorch_gconv
# creating build/lib/groupy/gfunc
# copying groupy/gfunc/p4func_array.py -> build/lib/groupy/gfunc
# copying groupy/gfunc/p4mfunc_array.py -> build/lib/groupy/gfunc
# copying groupy/gfunc/__init__.py -> build/lib/groupy/gfunc
# copying groupy/gfunc/gfuncarray.py -> build/lib/groupy/gfunc
# copying groupy/gfunc/test_gfuncarray.py -> build/lib/groupy/gfunc
# copying groupy/gfunc/z2func_array.py -> build/lib/groupy/gfunc
# creating build/lib/groupy/gfunc/plot
# copying groupy/gfunc/plot/plot_p4m.py -> build/lib/groupy/gfunc/plot
# copying groupy/gfunc/plot/plot_z2.py -> build/lib/groupy/gfunc/plot
# copying groupy/gfunc/plot/__init__.py -> build/lib/groupy/gfunc/plot
# copying groupy/gfunc/plot/plot_p4.py -> build/lib/groupy/gfunc/plot
# running install_lib
# creating /opt/conda/lib/python3.7/site-packages/groupy
# creating /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/p4_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/C4_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/garray.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/p4m_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/finitegroup.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/matrix_garray.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/Z2_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/D4_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# copying build/lib/groupy/garray/test_garray.py -> /opt/conda/lib/python3.7/site-packages/groupy/garray
# creating /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/p4func_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/p4mfunc_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/gfuncarray.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/test_gfuncarray.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# copying build/lib/groupy/gfunc/z2func_array.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc
# creating /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot
# copying build/lib/groupy/gfunc/plot/plot_p4m.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot
# copying build/lib/groupy/gfunc/plot/plot_z2.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot
# copying build/lib/groupy/gfunc/plot/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot
# copying build/lib/groupy/gfunc/plot/plot_p4.py -> /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot
# copying build/lib/groupy/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy
# creating /opt/conda/lib/python3.7/site-packages/groupy/gconv
# creating /opt/conda/lib/python3.7/site-packages/groupy/gconv/theano_gconv
# copying build/lib/groupy/gconv/theano_gconv/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/theano_gconv
# creating /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# copying build/lib/groupy/gconv/tensorflow_gconv/splitgconv2d.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# copying build/lib/groupy/gconv/tensorflow_gconv/transform_filter.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# copying build/lib/groupy/gconv/tensorflow_gconv/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# copying build/lib/groupy/gconv/tensorflow_gconv/check_gconv2d.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# copying build/lib/groupy/gconv/tensorflow_gconv/check_transform_filter.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv
# creating /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/pytorch_gconv/splitgconv2d.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/pytorch_gconv/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/pytorch_gconv/pooling.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/pytorch_gconv/check_gconv2d.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/pytorch_gconv/check_transform_filter.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv
# copying build/lib/groupy/gconv/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv
# copying build/lib/groupy/gconv/make_gconv_indices.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv
# creating /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/splitgconv2d.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/transform_filter.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/test_transform_filter.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/__init__.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/test_gconv.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/p4_conv.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# copying build/lib/groupy/gconv/chainer_gconv/p4m_conv.py -> /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/p4_array.py to p4_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/C4_array.py to C4_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/garray.py to garray.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/p4m_array.py to p4m_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/finitegroup.py to finitegroup.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/matrix_garray.py to matrix_garray.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/Z2_array.py to Z2_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/D4_array.py to D4_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/garray/test_garray.py to test_garray.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/p4func_array.py to p4func_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/p4mfunc_array.py to p4mfunc_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/gfuncarray.py to gfuncarray.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/test_gfuncarray.py to test_gfuncarray.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/z2func_array.py to z2func_array.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot/plot_p4m.py to plot_p4m.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot/plot_z2.py to plot_z2.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gfunc/plot/plot_p4.py to plot_p4.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/theano_gconv/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv/splitgconv2d.py to splitgconv2d.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv/transform_filter.py to transform_filter.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv/check_gconv2d.py to check_gconv2d.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/tensorflow_gconv/check_transform_filter.py to check_transform_filter.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv/splitgconv2d.py to splitgconv2d.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv/pooling.py to pooling.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv/check_gconv2d.py to check_gconv2d.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/pytorch_gconv/check_transform_filter.py to check_transform_filter.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/make_gconv_indices.py to make_gconv_indices.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/splitgconv2d.py to splitgconv2d.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/transform_filter.py to transform_filter.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/test_transform_filter.py to test_transform_filter.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/__init__.py to __init__.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/test_gconv.py to test_gconv.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/p4_conv.py to p4_conv.cpython-37.pyc
# byte-compiling /opt/conda/lib/python3.7/site-packages/groupy/gconv/chainer_gconv/p4m_conv.py to p4m_conv.cpython-37.pyc
# running install_egg_info
# Writing /opt/conda/lib/python3.7/site-packages/GrouPy-0.1.2-py3.7.egg-info
# /kaggle/working

# %%
# Here we have some useful imports for the train
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, utils
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
from torch.autograd import Variable
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from torch.optim.lr_scheduler import MultiStepLR
import torch.backends.cudnn as cudnn

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Here we download the CIFAR10 dataset (trainset and testset)
trainset = datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

testset = datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Useful function to visualize samples

def visualize_samples(inputs, title=None):
    """
    Visualization of transformed samples, a standard call:
        inputs, classes = next(iter(dataloaders['train']))
        visualize_samples(inputs)
    Arguments:
    batch_of_samples -- a batch from the dataloader; a PyTorch tensor of shape (batch_size, 3, 224, 224)

    Return:
    None (A nice plot)
    """
    
    # Make a grid from batch
    inp = utils.make_grid(inputs, nrow=12)

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)  # plotly accepts the colour information both in the 0-1 range and in the 0-255 range
    fig = px.imshow(inp, title=title)
    fig.show()


# Get a batch of training data
inputs = [trainset[i][0] for i in range(6)]
class_idx = [trainset[i][1] for i in range(6)]


visualize_samples(inputs, title=f'Make your prediction, which is the label of each image? The labels are<br> {[x for x in classes]}')  

# Solution
print(f'Ground truth: {[classes[x] for x in class_idx]}')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="dd982f13-218d-478e-9dd9-1fdbb2e74ef6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd982f13-218d-478e-9dd9-1fdbb2e74ef6")) {                    Plotly.newPlot(                        "dd982f13-218d-478e-9dd9-1fdbb2e74ef6",                        [{"name":"0","source":"data:image/png;base64,...","type":"image","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}<br>y: %{y}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlin ...
#
# var gd = docume
# Ground truth: ['frog', 'truck', 'truck', 'deer', 'car', 'car']

# %%
# Useful import for using G-CNN
from groupy.gconv.pytorch_gconv.splitgconv2d import P4MConvZ2, P4MConvP4M

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = P4MConvP4M(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm3d(planes)
        self.conv2 = P4MConvP4M(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm3d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                P4MConvP4M(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm3d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = P4MConvP4M(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm3d(planes)
        self.conv2 = P4MConvP4M(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm3d(planes)
        self.conv3 = P4MConvP4M(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm3d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                P4MConvP4M(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm3d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 23

        self.conv1 = P4MConvZ2(3, 23, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm3d(23)
        self.layer1 = self._make_layer(block, 23, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 45, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 91, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 181, num_blocks[3], stride=2)
        self.linear = nn.Linear(181*8*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        outs = out.size()
        out = out.view(outs[0], outs[1]*outs[2], outs[3], outs[4])
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %%
# We want to print the training loss every log_freq batches
log_freq = len(trainset)//128  # default 

def train(epoch, net, optimizer, loss_func, log_freq=log_freq):
    running_loss = 0.0
    for i, data in enumerate(trainloader, start=1):
        # get the inputs
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if (i) % log_freq == 0:    # print every log_freq mini-batches
            print('[Epoch : %d, Iter: %5d] loss: %.3f' %
                  (epoch + 1, i, running_loss / log_freq))
            running_loss = 0.0
    return running_loss / log_freq

def test(net, train_data=False):
    if train_data:
        print("Accuracy on training data")
        dataloader = trainloader
    else:
        print("Accuracy on test data")
        dataloader = testloader
    class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    with torch.no_grad():
        for batch_idx, data in enumerate(dataloader):
            if batch_idx == len(testloader):
                break
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            output = net(inputs)
            _, predicted = torch.max(output, 1)
            c = (predicted == labels).squeeze()
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1


    for i in range(10):
        print('Accuracy of %5s : %.2f %%' % (
            classes[i], 100 * class_correct[i] / class_total[i]))

    test_score = np.mean([100 * class_correct[i] / class_total[i] for i in range(10)])
    print(test_score)
    return test_score

# %% [markdown]
# In the cell below the model train is done, the numer of epochs is equal to 140, that represents a good threshold in order to obtain nice results
# The entire training take almost **10 hours** and I decided to use the accelerator GPU P100.

# %%
from tqdm.notebook import tqdm

run_training = True  #@param {type:"boolean"}
SAVE_PATH = "./data/" #@param
epoch_num = 140
PATH = SAVE_PATH + 'ckpt.pt'
test_freq = 10
resume = 1
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

if run_training:
    net = ResNet18()
    learning_rate = 0.05
    momentum = 0.9
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum,
                            weight_decay=5e-4)
    
    start_epoch = 0
    
    if device == 'cuda':
        net = torch.nn.DataParallel(net)
        cudnn.benchmark = True
    net.to(device)
    milestones = [50, 100, 140]
    scheduler = MultiStepLR(optimizer, milestones, gamma=0.1)
        
    for idx in tqdm(range(start_epoch, start_epoch + epoch_num)):
        net.train()
        loss = train(idx, net, optimizer, criterion)
        scheduler.step()

        if (idx+1) % test_freq == 0:
            print('\n-------------Network Test-------------')
            net.eval()
            test(net)
            test(net, train_data=True)
            print('----------------------------------------\n')
        torch.save({
              'epoch': idx,
              'model_state_dict': net.state_dict(),
              'optimizer_state_dict': optimizer.state_dict(),
              'loss': loss,
          }, PATH)
# Out:
# cuda:0
#   0%|          | 0/140 [00:00<?, ?it/s]
# [Epoch : 1, Iter:   390] loss: 2.060
# [Epoch : 2, Iter:   390] loss: 1.635
# [Epoch : 3, Iter:   390] loss: 1.332
# [Epoch : 4, Iter:   390] loss: 1.065
# [Epoch : 5, Iter:   390] loss: 0.793
# [Epoch : 6, Iter:   390] loss: 0.622
# [Epoch : 7, Iter:   390] loss: 0.514
# [Epoch : 8, Iter:   390] loss: 0.443
# [Epoch : 9, Iter:   390] loss: 0.387
# [Epoch : 10, Iter:   390] loss: 0.336
#
# -------------Network Test-------------
# Accuracy on test data
# Accuracy of plane : 93.80 %
# Accuracy of   car : 90.90 %
# Accuracy of  bird : 84.70 %
# Accuracy of   cat : 77.30 %
# Accuracy of  deer : 75.00 %
# Accuracy of   dog : 79.00 %
# Accuracy of  frog : 82.50 %
# Accuracy of horse : 87.20 %
# Accuracy of  ship : 92.00 %
# Accuracy of truck : 87.70 %
# 85.01
# Accuracy on training data
# Accuracy of plane : 96.37 %
# Accuracy of   car : 93.85 %
# Accuracy of  bird : 87.91 %
# Accuracy of   cat : 84.99 %
# Accuracy of  deer : 77.57 %
# Accuracy of   dog : 83.10 %
# Accuracy of  frog : 82.54 %
# Accuracy of horse : 89.01 %
# Accuracy of  ship : 91.83 %
# Accuracy of truck : 89.52 %
# 87.66931479398828
# ----------------------------------------
#
# [Epoch : 11, Iter:   390] loss: 0.304
# [Epoch : 12, Iter:   390] loss: 0.277
# [Epoch : 13, Iter:   390] loss: 0.252
# [Epoch : 14, Iter:   390] loss: 0.237
# [Epoch : 15, Iter:   390] loss: 0.212
# [Epoch : 16, Iter:   390] loss: 0.201
# [Epoch : 17, Iter:   390] loss: 0.197
# [Epoch : 18, Iter:   390] loss: 0.181
# [Epoch : 19, Iter:   390] loss: 0.175
# [Epoch : 20, Iter:   390] loss: 0.165
#
# -------------Network Test-------------
# Accuracy on test data
# Accuracy of plane :
# [Epoch : 139, Iter:   390] loss: 0.001
# [Epoch : 140, Iter:   390] loss: 0.001
#
# -------------Network Test-------------
# Accuracy on test data
# Accuracy of plane : 96.40 %
# Accuracy of   car : 98.00 %
# Accuracy of  bird : 94.60 %
# Accuracy of   cat : 90.80 %
# Accuracy of  deer : 95.30 %
# Accuracy of   dog : 89.10 %
# Accuracy of  frog : 97.60 %
# Accuracy of horse : 96.20 %
# Accuracy of  ship : 97.40 %
# Accuracy of truck : 96.30 %
# 95.16999999999999
# Accuracy on training data
# Accuracy of plane : 100.00 %
# Accuracy of   car : 100.00 %
# Accuracy of  bird : 100.00 %
# Accuracy of   cat : 100.00 %
# Accuracy of  deer : 100.00 %
# Accuracy of   dog : 100.00 %
# Accuracy of  frog : 100.00 %
# Accuracy of horse : 100.00 %
# Accuracy of  ship : 100.00 %
# Accuracy of truck : 100.00 %
# 100.0
# ----------------------------------------

# %% [markdown]
# Since loading the data contained in the Kaggle output folders takes a very long time to load, I decided to zip the whole folder so that it could be downloaded.

# %%
# !zip -r file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/GrouPy/ (stored 0%)
#   adding: kaggle/working/GrouPy/.gitignore (deflated 49%)
#   adding: kaggle/working/GrouPy/p4m_fmaps.png (deflated 3%)
#   adding: kaggle/working/GrouPy/setup.py (deflated 48%)
#   adding: kaggle/working/GrouPy/p4_fmaps.png (deflated 1%)
#   adding: kaggle/working/GrouPy/LICENSE (deflated 40%)
#   adding: kaggle/working/GrouPy/.git/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/branches/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/info/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/info/exclude (deflated 28%)
#   adding: kaggle/working/GrouPy/.git/logs/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/remotes/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/heads/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/logs/refs/heads/master (deflated 27%)
#   adding: kaggle/working/GrouPy/.git/logs/HEAD (deflated 27%)
#   adding: kaggle/working/GrouPy/.git/refs/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/tags/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/remotes/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/heads/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/refs/heads/master (stored 0%)
#   adding: kaggle/working/GrouPy/.git/description (deflated 14%)
#   adding: kaggle/working/GrouPy/.git/index (deflated 59%)
#   adding: kaggle/working/GrouPy/.git/config (deflated 33%)
#   adding: kaggle/working/GrouPy/.git/hooks/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: kaggle/working/GrouPy/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: kaggle/working/GrouPy/.git/hooks/fsmonitor-watchman.sample (deflated 52%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-push.sample (deflated 50%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: kaggle/working/GrouPy/.git/hooks/update.sample (deflated 68%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: kaggle/working/GrouPy/.git/hooks/post-update.sample (deflated 27%)
#   adding: kaggle/working/GrouPy/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: kaggle/working/GrouPy/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: kaggle/working/GrouPy/.git/packed-refs (deflated 10%)
#   adding: kaggle/working/GrouPy/.git/HEAD (stored 0%)
#   adding: kaggle/working/GrouPy/.git/objects/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/objects/info/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/objects/pack/ (stored 0%)
#   adding: kaggle/working/GrouPy/.git/objects/pack/pack-700f4e3256b812b1b16fb184d4511c915996e13c.idx (deflated 14%)
#   adding: kaggle/working/GrouPy/.git/objects/pack/pack-700f4e3256b812b1b16fb184d4511c915996e13c.pack (deflated 1%)
#   adding: kaggle/working/GrouPy/build/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/check_gconv2d.py (deflated 78%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/splitgconv2d.py (deflated 74%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/check_transform_filter.py (deflated 76%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/pooling.py (deflated 42%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/pytorch_gconv/__init__.py (deflated 29%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/splitgconv2d.py (deflated 68%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/p4m_conv.py (deflated 62%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/test_gconv.py (deflated 80%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/test_transform_filter.py (deflated 69%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/p4_conv.py (deflated 62%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/__init__.py (deflated 50%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/chainer_gconv/transform_filter.py (deflated 63%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/theano_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/theano_gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/make_gconv_indices.py (deflated 68%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/check_gconv2d.py (deflated 63%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/splitgconv2d.py (deflated 66%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/check_transform_filter.py (deflated 73%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gconv/tensorflow_gconv/transform_filter.py (deflated 77%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/Z2_array.py (deflated 63%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/matrix_garray.py (deflated 74%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/p4_array.py (deflated 68%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/finitegroup.py (deflated 67%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/p4m_array.py (deflated 70%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/C4_array.py (deflated 66%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/garray.py (deflated 68%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/D4_array.py (deflated 68%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/test_garray.py (deflated 71%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/garray/__init__.py (deflated 66%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/z2func_array.py (deflated 58%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/p4mfunc_array.py (deflated 61%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/plot/ (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/plot/plot_z2.py (deflated 56%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/plot/plot_p4m.py (deflated 82%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/plot/plot_p4.py (deflated 74%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/plot/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/p4func_array.py (deflated 59%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/test_gfuncarray.py (deflated 75%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/gfuncarray.py (deflated 67%)
#   adding: kaggle/working/GrouPy/build/lib/groupy/gfunc/__init__.py (deflated 58%)
#   adding: kaggle/working/GrouPy/README.md (deflated 62%)
#   adding: kaggle/working/GrouPy/groupy/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/check_gconv2d.py (deflated 78%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/splitgconv2d.py (deflated 74%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/check_transform_filter.py (deflated 76%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/pooling.py (deflated 42%)
#   adding: kaggle/working/GrouPy/groupy/gconv/pytorch_gconv/__init__.py (deflated 29%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/splitgconv2d.py (deflated 68%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/kernels/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/kernels/integer_indexing_cuda_kernel.py (deflated 79%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/kernels/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/kernels/test_integer_indexing_cuda_kernel.py (deflated 58%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/p4m_conv.py (deflated 62%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/test_gconv.py (deflated 80%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/test_transform_filter.py (deflated 69%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/p4_conv.py (deflated 62%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/pooling/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/pooling/plane_group_spatial_max_pooling.py (deflated 46%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/pooling/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/__init__.py (deflated 50%)
#   adding: kaggle/working/GrouPy/groupy/gconv/chainer_gconv/transform_filter.py (deflated 63%)
#   adding: kaggle/working/GrouPy/groupy/gconv/theano_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/theano_gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/make_gconv_indices.py (deflated 68%)
#   adding: kaggle/working/GrouPy/groupy/gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/check_gconv2d.py (deflated 63%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/splitgconv2d.py (deflated 66%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/check_transform_filter.py (deflated 73%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gconv/tensorflow_gconv/transform_filter.py (deflated 77%)
#   adding: kaggle/working/GrouPy/groupy/garray/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/garray/Z2_array.py (deflated 63%)
#   adding: kaggle/working/GrouPy/groupy/garray/matrix_garray.py (deflated 74%)
#   adding: kaggle/working/GrouPy/groupy/garray/p4_array.py (deflated 68%)
#   adding: kaggle/working/GrouPy/groupy/garray/finitegroup.py (deflated 67%)
#   adding: kaggle/working/GrouPy/groupy/garray/p4m_array.py (deflated 70%)
#   adding: kaggle/working/GrouPy/groupy/garray/C4_array.py (deflated 66%)
#   adding: kaggle/working/GrouPy/groupy/garray/garray.py (deflated 68%)
#   adding: kaggle/working/GrouPy/groupy/garray/D4_array.py (deflated 68%)
#   adding: kaggle/working/GrouPy/groupy/garray/test_garray.py (deflated 71%)
#   adding: kaggle/working/GrouPy/groupy/garray/__init__.py (deflated 66%)
#   adding: kaggle/working/GrouPy/groupy/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/z2func_array.py (deflated 58%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/p4mfunc_array.py (deflated 61%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/plot/ (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/plot/plot_z2.py (deflated 56%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/plot/plot_p4m.py (deflated 82%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/plot/plot_p4.py (deflated 74%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/plot/__init__.py (stored 0%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/p4func_array.py (deflated 59%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/test_gfuncarray.py (deflated 75%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/gfuncarray.py (deflated 67%)
#   adding: kaggle/working/GrouPy/groupy/gfunc/__init__.py (deflated 58%)
#   adding: kaggle/working/GrouPy/requirements.txt (stored 0%)
#   adding: kaggle/working/GrouPy/p4_anim.gif (deflated 5%)
#   adding: kaggle/working/__notebook_source__.ipynb (deflated 44%)
#   adding: kaggle/working/DeepLearningProject/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/CIFAR10/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/CIFAR10/readme (deflated 35%)
#   adding: kaggle/working/DeepLearningProject/.git/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/branches/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/info/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/info/exclude (deflated 28%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/remotes/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/heads/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/refs/heads/main (deflated 27%)
#   adding: kaggle/working/DeepLearningProject/.git/logs/HEAD (deflated 27%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/tags/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/remotes/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/heads/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/refs/heads/main (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/description (deflated 14%)
#   adding: kaggle/working/DeepLearningProject/.git/index (deflated 29%)
#   adding: kaggle/working/DeepLearningProject/.git/config (deflated 32%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/fsmonitor-watchman.sample (deflated 52%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-push.sample (deflated 50%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/update.sample (deflated 68%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/post-update.sample (deflated 27%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: kaggle/working/DeepLearningProject/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: kaggle/working/DeepLearningProject/.git/packed-refs (deflated 10%)
#   adding: kaggle/working/DeepLearningProject/.git/HEAD (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b1/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b1/3e1d07fdd4f748e60f714d33f4e76980dab00f (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/8b/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/8b/137891791fe96927ad78e64b0aad7bded08bdc (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ab/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ab/81127a7c8bac281a466eb3991e469367c79a77 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/76/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/76/123b561cc6606f802be0dec861ce2f7c9e9304 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/d4/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/d4/930ae0f9308ef022994792217657a30fced655 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/4d/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/4d/1af238bcdd19f31a4465362a6f3fb230138047 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/24/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/24/a083817b30f3afa90fd53a431bcf790b92fe4d (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/fe/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/fe/414a3f0b438cdcdeb888db096d44f4ca730c39 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/87/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/87/16c8308f5f0ff61db3525dbabefca4418aa564 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b3/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b3/817cde59a918c3c4c2969b5f5c7bc00249ae4b (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/info/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/4f/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/4f/1c64ac13408d4600a08fc9206b49188026958f (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b6/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/b6/db2b59043d82290e829d2f9dd6ba6ddd898fe0 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/dd/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/dd/7a36baa183af62f06f643675441f7e30ed687c (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/58/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/58/7117e72551d70bcf0952bd855d4889f2c8a30a (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ec/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ec/c3ed4f0d2556dd60ec2ccc53b1bc549e61cd22 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/d3/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/d3/aeb036fc0d373b6f2e7e230a48ae8d74ac17b6 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/pack/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/33/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/33/dfa0488e5b3fd2885d421e2a5c62b7b35ad766 (deflated 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/a0/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/a0/69210dae9ab1132700969b8ad78f6371779a0e (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/a0/c809bbcc2b442103ccf14c7617f3dca5590d5a (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ad/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ad/1977e2135f2dcda6d2e4e12299d8d83cd59be0 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/da/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/da/6c2b60daf34aafa9256e20a405d7c6c82a1607 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/1c/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/1c/c27ef7c78b64fb326c591a2571ccac3476f525 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ac/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ac/4346abe01c0899f00331d37c44c3f2098dcb53 (deflated 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/ac/a33b2a2ebbe0059cfeba42eb89ebe66858d8ca (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/a8/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/a8/f2c5de0754a298ab4a13e8ac1053bcdd7e3fd3 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/02/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/02/65c67b6613253db1a6ba54d37979ed3028a77b (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/02/ff121c06a5e14230f9d8f0a83b2babe4ffecd1 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/47/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/47/64deefb213f57e2843bad37498aae24cf7dbc9 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/6c/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/6c/441d72828b1e7369b96cecd2edbfc61db5a133 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/16/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/16/b9f90ca13937d2816dee47f4d5ab1edd6a397d (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/cb/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/cb/45079f2cf278877689c915f1c8fbed440c8cd6 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/eb/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/eb/a8db254ef2a0bd13aee6d245ce05ec3c34c1e2 (deflated 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/7f/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/7f/06dd54302d23f7b108e5e9b0aae9b67efc8833 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/c8/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/c8/7e8b7dcf43fe55f7865e6f716b2a34f0cc8b03 (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/7e/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/7e/586a7d8f7fc24d9a49522f32095fe0fdf7e3cb (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/61/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/61/9bfe4e23730ce9df6fe0611053fc7d2a7f468a (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/8c/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/.git/objects/8c/fb60272828f2ed839b4f0ffa336e2c45cf255c (stored 0%)
#   adding: kaggle/working/DeepLearningProject/RotatedMNIST/ (stored 0%)
#   adding: kaggle/working/DeepLearningProject/RotatedMNIST/datackp.pt (deflated 8%)
#   adding: kaggle/working/DeepLearningProject/RotatedMNIST/mnist (stored 0%)
#   adding: kaggle/working/DeepLearningProject/README.md (deflated 30%)
#   adding: kaggle/working/data/ (stored 0%)
#   adding: kaggle/working/data/cifar-10-batches-py/ (stored 0%)
#   adding: kaggle/working/data/cifar-10-batches-py/batches.meta (deflated 12%)
#   adding: kaggle/working/data/cifar-10-batches-py/test_batch (deflated 8%)
#   adding: kaggle/working/data/cifar-10-batches-py/data_batch_2 (deflated 8%)
#   adding: kaggle/working/data/cifar-10-batches-py/data_batch_4 (deflated 8%)
#   adding: kaggle/working/data/cifar-10-batches-py/data_batch_5 (deflated 8%)
#   adding: kaggle/working/data/cifar-10-batches-py/data_batch_1 (deflated 9%)
#   adding: kaggle/working/data/cifar-10-batches-py/readme.html (stored 0%)
#   adding: kaggle/working/data/cifar-10-batches-py/data_batch_3 (deflated 8%)
#   adding: kaggle/working/data/cifar-10-python.tar.gz (deflated 0%)
#   adding: kaggle/working/data/ckpt.pt (deflated 7%)
